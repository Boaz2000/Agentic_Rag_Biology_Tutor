# %%
# !pip install --quiet langchain-community langchain-text-splitters langchain-chroma langchain-google-genai pypdf
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 378.1/378.1 kB 27.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 74.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 34.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.7/561.7 kB 40.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 6.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 22.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 87.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 73.7 MB/s eta 0:00:00
# ...

# %%
'''import os
from pathlib import Path
from google.colab import userdata  # ספרייה מובנית של קולאב לשליפת Secrets
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai.embeddings import GoogleGenerativeAIEmbeddings

# 2. שליפת ה-API Key בצורה מאובטחת מה-Secrets של קולאב
os.environ["Gemini_API_Key"] = userdata.get('Gemini_API_Key')

print("📄 שלב 1: סורק את כל התיקיות והתת-תיקיות וטוען קבצי PDF...")
loader = PyPDFDirectoryLoader(".", recursive=True)
docs = loader.load()
print(f"✅ שלב 1 הסתיים! נטענו בהצלחה {len(docs)} עמודים מכל התיקיות.")

print("\n✂️ שלב 2: מחלק את הטקסט למקטעים (Chunks)...")
text_splitter = RecursiveCharacterTextSplitter(chunk_size=700, chunk_overlap=100)
chunks = text_splitter.split_documents(docs)
print(f"✅ שלב 2 הסתיים! הטקסט פוצל ל-{len(chunks)} מקטעים.")

print("\n🌐 שלב 3: מקודד ומייצר את בסיס הנתונים הוקטורי (Chroma)...")
embedding_model = GoogleGenerativeAIEmbeddings(model="models/embedding-001", google_api_key=userdata.get('Gemini_API_Key'))

db = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model,
    persist_directory="./chroma_db"
)

print("\n🏆 בינגו! המחסן הוקטורי נוצר בהצלחה בתיקיית chroma_db!")

# 3. כיווץ התיקייה לקובץ ZIP
# !zip -r chroma_db.zip ./chroma_db
print("📦 התיקייה מכווצת ומוכנה להורדה כ-chroma_db.zip!")'''
# Out:
# 📄 שלב 1: סורק את כל התיקיות והתת-תיקיות וטוען קבצי PDF...
# ✅ שלב 1 הסתיים! נטענו בהצלחה 595 עמודים מכל התיקיות.
#
# ✂️ שלב 2: מחלק את הטקסט למקטעים (Chunks)...
# ✅ שלב 2 הסתיים! הטקסט פוצל ל-2791 מקטעים.
#
# 🌐 שלב 3: מקודד ומייצר את בסיס הנתונים הוקטורי (Chroma)...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/embeddings.py in embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     448             try:
# --> 449                 result = self.client.models.embed_content(
#     450                     model=self.model,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in embed_content(self, model, contents, config)
#    5724     if not self._api_client.vertexai:
# -> 5725       return self._embed_content(model=model, contents=contents, config=config)
#    5726
#
# ...

# %%
'''import os
from google.colab import userdata
from google import genai
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_core.embeddings import Embeddings

# 2. אתחול הלקוח הרשמי של גוגל עם ה-Secret שלך
api_key = userdata.get('Gemini_API_Key')
client = genai.Client(api_key=api_key)

# יצירת מחלקה מותאמת אישית שלוקחת את ה-Embeddings ישירות מגוגל בלי תיווך של LangChain
class DirectGoogleEmbeddings(Embeddings):
    def embed_documents(self, texts):
        response = client.models.embed_content(
            model="text-embedding-001",
            contents=texts
        )
        return [e.values for e in response.embeddings]

    def embed_query(self, text):
        response = client.models.embed_content(
            model="text-embedding-001",
            contents=text
        )
        return response.embeddings[0].values

print("📄 שלב 1: סורק את כל התיקיות וטוען קבצי PDF...")
loader = PyPDFDirectoryLoader(".", recursive=True)
docs = loader.load()
print(f"✅ נטענו בהצלחה {len(docs)} עמודים.")

print("\n✂️ שלב 2: מחלק את הטקסט למקטעים (Chunks)...")
text_splitter = RecursiveCharacterTextSplitter(chunk_size=700, chunk_overlap=100)
chunks = text_splitter.split_documents(docs)
print(f"✅ הטקסט פוצל ל-{len(chunks)} מקטעים.")

print("\n🌐 שלב 3: מקודד ישירות מול גוגל ומייצר את Chroma DB...")
print("\n🌐 שלב 3: מקודד ישירות מול גוגל ומייצר את Chroma DB בחבילות...")
embedding_model = DirectGoogleEmbeddings()

# 1. יצירת בסיס הנתונים הריק בפעם הראשונה
db = Chroma(
    persist_directory="./chroma_db",
    embedding_function=embedding_model
)

# 2. לולאה חכמה שדוחפת בכל פעם 100 מקטעים כדי לעמוד במגבלות של גוגל
batch_size = 100
for i in range(0, len(chunks), batch_size):
    batch = chunks[i : i + batch_size]
    db.add_documents(batch)
    print(f"🔹 נשלח ועובד בהצלחה: מקטעים {i} עד {min(i + batch_size, len(chunks))}")

print("✅ המחסן הוקטורי נוצר בהצלחה!")
print("✅ המחסן הוקטורי נוצר בהצלחה!")

# 3. כיווץ התיקייה לקובץ ZIP
print("\n📦 מכווץ את התיקייה...")
# !zip -r chroma_db.zip ./chroma_db
print("🏆 בינגו אחי! הקובץ chroma_db.zip מוכן ומחכה לך בלשונית התיקיות!")'''
# Out:
# 📄 שלב 1: סורק את כל התיקיות וטוען קבצי PDF...
# ✅ נטענו בהצלחה 595 עמודים.
#
# ✂️ שלב 2: מחלק את הטקסט למקטעים (Chunks)...
# ✅ הטקסט פוצל ל-2791 מקטעים.
#
# 🌐 שלב 3: מקודד ישירות מול גוגל ומייצר את Chroma DB...
#
# 🌐 שלב 3: מקודד ישירות מול גוגל ומייצר את Chroma DB בחבילות...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_6107/1197528919.py in <cell line: 0>()
#      51 for i in range(0, len(chunks), batch_size):
#      52     batch = chunks[i : i + batch_size]
# ---> 53     db.add_documents(batch)
#      54     print(f"🔹 נשלח ועובד בהצלחה: מקטעים {i} עד {min(i + batch_size, len(chunks))}")
#      55
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/vectorstores/base.py in add_documents(self, documents, **kwargs)
#     256             texts = [doc.page_content for doc in documents]
#     257             metadatas = [doc.metadata for doc in documents]
# ...

# %%
import os
from pathlib import Path
from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_chroma import Chroma
from langchain_community.embeddings import HuggingFaceEmbeddings

print("📄 שלב 1: סורק את כל התיקיות וטוען קבצי PDF...")
loader = PyPDFDirectoryLoader(".", recursive=True)
docs = loader.load()
print(f"✅ נטענו בהצלחה {len(docs)} עמודים.")

print("\n✂️ שלב 2: מחלק את הטקסט למקטעים (Chunks)...")
text_splitter = RecursiveCharacterTextSplitter(chunk_size=700, chunk_overlap=100)
chunks = text_splitter.split_documents(docs)
print(f"✅ הטקסט פוצל ל-{len(chunks)} מקטעים.")

print("\n🌐 שלב 3: טוען מודל שפה מקומי ומייצר את Chroma DB...")
# שימוש במודל רב-לשוני עוצמתי שמבין עברית מושלם ורץ ישירות על השרת של קולאב
embedding_model = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-small")

db = Chroma.from_documents(
    documents=chunks,
    embedding=embedding_model,
    persist_directory="./chroma_db"
)
print("✅ המחסן הוקטורי נוצר בהצלחה בתוך שניות!")

# 3. כיווץ התיקייה לקובץ ZIP
print("\n📦 מכווץ את התיקייה...")
# !zip -r chroma_db.zip ./chroma_db
print("🏆 בינגו אחי! הקובץ chroma_db.zip מוכן ומחכה לך בלשונית התיקיות!")
# Out:
# 📄 שלב 1: סורק את כל התיקיות וטוען קבצי PDF...
# ✅ נטענו בהצלחה 595 עמודים.
#
# ✂️ שלב 2: מחלק את הטקסט למקטעים (Chunks)...
# ✅ הטקסט פוצל ל-2791 מקטעים.
#
# 🌐 שלב 3: טוען מודל שפה מקומי ומייצר את Chroma DB...
# /tmp/ipykernel_6107/4291687194.py:20: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="intfloat/multilingual-e5-small")
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...
